# %% [markdown]
# <a href="https://colab.research.google.com/github/jm-menon/Contacts-App/blob/main/SLM_P1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Uploading the Data from local -- "The Verdict' by Edith Wharton

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
with open('/content/sample_data/Data_edith_wharton.txt', 'r', encoding='utf-8') as f:
  data= f.read()

print("number of characters is: ", len(data))
print(data[:100])
# Out:
# number of characters is:  20482
# I HAD always thought Jack Gisburn rather a cheap genius--though a good fellow enough--so it was no g

# %% [markdown]
# Proceeding to tokenize this data of 20000+ characters, before we carry out the tokenize id + embedding later.

# %%
import re

#test= "Some, sample test this is !!! Yay."
result= re.split(r'([,.!?]|\s)', test)
print(result)
# Out:
# ['Some', ',', '', ' ', 'sample', ' ', 'test', ' ', 'this', ' ', 'is', ' ', '', '!', '', '!', '', '!', '', ' ', 'Yay', '.', '']
